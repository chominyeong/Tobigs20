# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
data = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ### 범주형
# - 명목형
#     - Attribution(종속변수)
#     - Department
#     - Education
#     - EducationField
#     - Gender
#     - JobRole
#     - MaritalStatus
#     - Over18
#     - OverTime
#
# - 순서형
#     - BusinessTravel
#     - DailyRate
#     - EnvironmentSatisfaction
#     - JobInvolvement
#     - JobLevel
#     - JobSatisfaction
#     - RelationshipSatisfaction
#     - StockOptionLevel
#     - WorkLifeBalance

# %% [markdown]
# ### 수치형
# - 연속형
# - 이산형
#     - Age
#     - DistanceFromHome
#     - EmployeeCount
#     - EmployeeNumber
#     - HourlyRate
#     - MonthlyIncome
#     - MonthlyRate
#     - NumCompaniesWorked
#     - PercentSalaryHike
#     - PerformanceRating
#     - StandardHours
#     - TotalWorkingYears
#     - TrainingTimesLastYear
#     - YearsAtCompany
#     - YearsInCurrentRole
#     - YearsSinceLastPromotion
#     - YearsWithCurrManager

# %% [markdown]
# ### 결측치

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# <U>결측 없음</U>

# %% [markdown]
# ### 이상치

# %%
fig, ax = plt.subplots(ncols=3, nrows=2, figsize=(20,15))

sns.boxplot(data['Age'], ax=ax[0,0])
sns.boxplot(data['DistanceFromHome'], ax=ax[0,1])
sns.boxplot(data['EmployeeCount'], ax=ax[0,2])
sns.boxplot(data['EmployeeNumber'], ax=ax[1,0])
sns.boxplot(data['HourlyRate'], ax=ax[1,1])
sns.boxplot(data['MonthlyIncome'], ax=ax[1,2])

plt.show()

# %%
fig, ax = plt.subplots(ncols=3, nrows=2, figsize=(20,15))

sns.boxplot(data['MonthlyRate'], ax=ax[0,0])
sns.boxplot(data['NumCompaniesWorked'], ax=ax[0,1])
sns.boxplot(data['PercentSalaryHike'], ax=ax[0,2])
sns.boxplot(data['PerformanceRating'], ax=ax[1,0])
sns.boxplot(data['StandardHours'], ax=ax[1,1])
sns.boxplot(data['TotalWorkingYears'], ax=ax[1,2])

plt.show()

# %%
fig, ax = plt.subplots(ncols=3, nrows=2, figsize=(20,15))

sns.boxplot(data['TrainingTimesLastYear'], ax=ax[0,0])
sns.boxplot(data['YearsAtCompany'], ax=ax[0,1])
sns.boxplot(data['YearsInCurrentRole'], ax=ax[0,2])
sns.boxplot(data['YearsSinceLastPromotion'], ax=ax[1,0])
sns.boxplot(data['YearsWithCurrManager'], ax=ax[1,1])

plt.show()

# %% [markdown]
# 이상치 존재 변수 : MonthlyIncome, NumCompaniesWorked, PerformanceRating, TotalWorkingYears, TrainingTimesLastYear,
#     YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager

# %%
# 이상치 개수
def count_outlier(column):
    q3 = data[column].quantile(0.75)
    q1 = data[column].quantile(0.25)
    iqr = q3 - q1
    
    condition = (data[column] > q3+1.5*iqr) | (data[column] < q1-1.5*iqr)
    return(len(data[condition]))

# %%
print("변수별 이상치 개수", "\n")
for i in ['MonthlyIncome', 'NumCompaniesWorked', 'PerformanceRating', 'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']:
    print(i,":", count_outlier(i))
    print()
# Out:
# 변수별 이상치 개수
#
# MonthlyIncome : 114
#
# NumCompaniesWorked : 52
#
# PerformanceRating : 226
#
# TotalWorkingYears : 63
#
# TrainingTimesLastYear : 238
#
# YearsAtCompany : 104
#
# YearsInCurrentRole : 21
#
# YearsSinceLastPromotion : 107
#
# YearsWithCurrManager : 14

# %% [markdown]
# ### 시각화

# %%
data.Attrition.astype('category')
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: category
# Categories (2, object): ['No', 'Yes']

# %%
# 히스토그램으로 수치데이터에 대한 분포 파악하기

# %%
data.hist(figsize=(15,15))
plt.show()

# %%
## 편향된 분포를 가진 변수들은 로그변환을 취해줘도 좋을 것 같다.

# %%
data.Attrition.value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
# 종속변수인 Attrition에 따른 히스토그램 차이 확인하기

# %%
for i in data.select_dtypes(include=['int64', 'float64']).columns:
    sns.set(rc={'figure.figsize':(5,5)})
    sns.histplot(data, x=i, hue='Attrition')
    plt.show()

# %%
# 범주형 변수 bar chart로 확인하기

# %%
obj_col = data.select_dtypes(include = 'object')

plt.figure(figsize=(14,25))
for i,col in enumerate(obj_col):
    axes = plt.subplot(4,3, i + 1)
    sns.countplot(x=data[col])
    plt.xticks(rotation = 30)
plt.tight_layout()
plt.show()

# %%
## Over18은 제외
data.Over18.value_counts()
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %%
data.drop(['Over18'], axis=1, inplace=True)

# %% [markdown]
# ### 상관관계

# %%
plt.figure(figsize = (30,20))
sns.heatmap(data.corr(),annot = True)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12432\1712676779.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot = True)

# %% [markdown]
# ### 파생변수

# %%
## 파트너 유무
data["Partner"]=data["MaritalStatus"].replace({"Married":"Yes", "Divorced":"No", "Single":"No"})
